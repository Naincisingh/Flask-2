# %%
"""QTS.1
GET requests are intended to retrieve data from a server and do not modify
the server's state. On the other hand, POST requests are used to send data to
the server for processing and may modify the server's state."""
# Out:
# "QTS.1\nGET requests are intended to retrieve data from a server and do not modify\nthe server's state. On the other hand, POST requests are used to send data to\nthe server for processing and may modify the server's state."

# %%
"""QTS.2
The Request, in Flask, is an object that contains all the data sent from the Client to Server. 
This data can be recovered using the GET/POST Methods."""
# Out:
# 'QTS.2\nThe Request, in Flask, is an object that contains all the data sent from the Client to Server. \nThis data can be recovered using the GET/POST Methods.'

# %%
"""QTS.3
Why is redirect() used in Flask?
A redirect is used in the Flask class to send the user to a particular URL with the status code."""
# Out:
# 'QTS.3\nWhy is redirect() used in Flask?\nA redirect is used in the Flask class to send the user to a particular URL with the status code.'

# %%
"""QTS.4
Templates are files that contain static data as well as placeholders for dynamic data

Render_template is used to generate output from a template file based on the Jinja2 
engine that is found in the application's templates folder."""
# Out:
# "QTS.4\nTemplates are files that contain static data as well as placeholders for dynamic data\n\nRender_template is used to generate output from a template file based on the Jinja2 \nengine that is found in the application's templates folder."

# %% [markdown]
# """QTS.5"""
# screenshots:-
# ![Screenshot (156).png](attachment:52995683-a789-4a8d-9fef-645794d80ab9.png)
# ![Screenshot (155).png](attachment:269739dd-945e-4c5d-b8f0-c1aeee2c13a4.png)
# ![Screenshot (158).png](attachment:508767ce-f20a-4c3e-a2e8-6ecded5f0687.png)
